# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# reading a csv file using pandas library
delivery_time=pd.read_csv("delivery_time.csv")
delivery_time
pd.set_option('display.min_rows', None)

# %%
delivery_time
# Out:
#     DeliveryTime  SortingTime
# 0          21.00           10
# 1          13.50            4
# 2          19.75            6
# 3          24.00            9
# 4          29.00           10
# 5          15.35            6
# 6          19.00            7
# 7           9.50            3
# 8          17.90           10
# 9          18.75            9
# 10         19.83            8
# 11         10.75            4
# 12         16.68            7
# 13         11.50            3
# 14         12.03            3
# 15         14.88            4
# 16         13.75            6
# 17         18.11            7
# 18          8.00            2
# 19         17.83            7
# 20         21.50            5

# %%
delivery_time.shape
# Out:
# (21, 2)

# %%
delivery_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DeliveryTime  21 non-null     float64
#  1   SortingTime   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
delivery_time.isnull()
# Out:
#     DeliveryTime  SortingTime
# 0          False        False
# 1          False        False
# 2          False        False
# 3          False        False
# 4          False        False
# 5          False        False
# 6          False        False
# 7          False        False
# 8          False        False
# 9          False        False
# 10         False        False
# 11         False        False
# 12         False        False
# 13         False        False
# 14         False        False
# 15         False        False
# 16         False        False
# 17         False        False
# 18         False        False
# 19         False        False
# 20         False        False

# %%
delivery_time.isnull().sum()
# Out:
# DeliveryTime    0
# SortingTime     0
# dtype: int64

# %%
delivery_time.describe()
# Out:
#        DeliveryTime  SortingTime
# count     21.000000    21.000000
# mean      16.790952     6.190476
# std        5.074901     2.542028
# min        8.000000     2.000000
# 25%       13.500000     4.000000
# 50%       17.830000     6.000000
# 75%       19.750000     8.000000
# max       29.000000    10.000000

# %%
delivery_time.columns
# Out:
# Index(['DeliveryTime', 'SortingTime'], dtype='object')

# %%
delivery_time.head()
# Out:
#    DeliveryTime  SortingTime
# 0         21.00           10
# 1         13.50            4
# 2         19.75            6
# 3         24.00            9
# 4         29.00           10

# %%
delivery_time.tail()
# Out:
#     DeliveryTime  SortingTime
# 16         13.75            6
# 17         18.11            7
# 18          8.00            2
# 19         17.83            7
# 20         21.50            5

# %%
plt.boxplot(delivery_time.DeliveryTime)
plt.show()

# %%
plt.hist(delivery_time.DeliveryTime)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
sns.distplot(delivery_time['DeliveryTime'])
plt.show()

# %%
plt.boxplot(delivery_time.SortingTime)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
sns.distplot(delivery_time['SortingTime'])
plt.show()

# %%
plt.plot(delivery_time["DeliveryTime"],delivery_time["DeliveryTime"],"rs")
plt.xlabel("DeliveryTime")
plt.ylabel("SortingTime")
plt.title("ScatterPlot")
# Out:
# Text(0.5, 1.0, 'ScatterPlot')

# %%
delivery_time.corr()
# Out:
#               DeliveryTime  SortingTime
# DeliveryTime      1.000000     0.825997
# SortingTime       0.825997     1.000000

# %%
import statsmodels.formula.api as smf
model = smf.ols("DeliveryTime~SortingTime", data=delivery_time).fit()
model.params
# Out:
# Intercept      6.582734
# SortingTime    1.649020
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           DeliveryTime   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     40.80
# Date:                Thu, 22 Feb 2024   Prob (F-statistic):           3.98e-06
# Time:                        05:58:11   Log-Likelihood:                -51.357
# No. Observations:                  21   AIC:                             106.7
# Df Residuals:                      19   BIC:                             108.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       6.5827      1.722      3.823      0.001       2.979      10.186
# ...

# %%
pred = model.predict(delivery_time.SortingTime)
#pred = model.predict(wcat.iloc[:,0])
pred
# Out:
# 0     23.072933
# 1     13.178814
# 2     16.476853
# 3     21.423913
# 4     23.072933
# 5     16.476853
# 6     18.125873
# 7     11.529794
# 8     23.072933
# 9     21.423913
# 10    19.774893
# 11    13.178814
# 12    18.125873
# 13    11.529794
# 14    11.529794
# 15    13.178814
# 16    16.476853
# 17    18.125873
# 18     9.880774
# 19    18.125873
# 20    14.827833
# dtype: float64

# %%
model.resid
# Out:
# 0    -2.072933
# 1     0.321186
# 2     3.273147
# 3     2.576087
# 4     5.927067
# 5    -1.126853
# 6     0.874127
# 7    -2.029794
# 8    -5.172933
# 9    -2.673913
# 10    0.055107
# 11   -2.428814
# 12   -1.445873
# 13   -0.029794
# 14    0.500206
# 15    1.701186
# 16   -2.726853
# 17   -0.015873
# 18   -1.880774
# 19   -0.295873
# 20    6.672167
# dtype: float64

# %%
model.resid_pearson
# Out:
# array([-0.70630355,  0.10943679,  1.11524837,  0.87774154,  2.01950985,
#        -0.383949  ,  0.2978383 , -0.69160484, -1.76255624, -0.9110735 ,
#         0.01877637, -0.82756157, -0.49264758, -0.0101515 ,  0.17043364,
#         0.5796396 , -0.92911167, -0.00540844, -0.64082979, -0.10081191,
#         2.27338512])

# %%
rmse_lin = np.sqrt(np.mean((np.array(delivery_time['DeliveryTime'])-np.array(pred))**2))
rmse_lin
# Out:
# 2.7916503270617654

# %%
delivery_time.head(2)
# Out:
#    DeliveryTime  SortingTime
# 0          21.0           10
# 1          13.5            4

# %%
#import matplotlib.pylab as plt
plt.scatter(x=delivery_time['SortingTime'],y=delivery_time['DeliveryTime'],color='red')
plt.plot(delivery_time['SortingTime'],pred,color='black')
plt.xlabel('SortingTime')
plt.ylabel('DeliveryTime')
# Out:
# Text(0, 0.5, 'DeliveryTime')

# %%
model2 = smf.ols('DeliveryTime~np.log(SortingTime)',data=delivery_time).fit()
#model2.params
#model2.resid
#model2.resid_pearson

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           DeliveryTime   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     40.80
# Date:                Thu, 22 Feb 2024   Prob (F-statistic):           3.98e-06
# Time:                        06:01:55   Log-Likelihood:                -51.357
# No. Observations:                  21   AIC:                             106.7
# Df Residuals:                      19   BIC:                             108.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       6.5827      1.722      3.823      0.001       2.979      10.186
# ...

# %%
pred2 = model2.predict(pd.DataFrame(delivery_time['SortingTime']))
pred2
# Out:
# 0     21.982913
# 1     13.696517
# 2     17.363305
# 3     21.030094
# 4     21.982913
# 5     17.363305
# 6     18.757354
# 7     11.094889
# 8     21.982913
# 9     21.030094
# 10    19.964933
# 11    13.696517
# 12    18.757354
# 13    11.094889
# 14    11.094889
# 15    13.696517
# 16    17.363305
# 17    18.757354
# 18     7.428100
# 19    18.757354
# 20    15.714496
# dtype: float64

# %%
pred2
rmse_log = np.sqrt(np.mean((np.array(delivery_time['DeliveryTime'])-np.array(pred2))**2))
rmse_log
# Out:
# 2.733171476682066

# %%
pred2.corr(delivery_time.DeliveryTime)
# Out:
# 0.8339325279256242

# %%
plt.scatter(x=delivery_time['SortingTime'],y=delivery_time['DeliveryTime'],color='green')
plt.plot(delivery_time['SortingTime'],pred2,color='blue')
plt.xlabel('SortingTime')
plt.ylabel('DeliveryTime')
# Out:
# Text(0, 0.5, 'DeliveryTime')

# %%
#exponential model
model3 = smf.ols('np.log(DeliveryTime)~SortingTime',data=delivery_time).fit()
model3.params
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     np.log(DeliveryTime)   R-squared:                       0.711
# Model:                              OLS   Adj. R-squared:                  0.696
# Method:                   Least Squares   F-statistic:                     46.73
# Date:                  Thu, 22 Feb 2024   Prob (F-statistic):           1.59e-06
# Time:                          06:07:33   Log-Likelihood:                 7.7920
# No. Observations:                    21   AIC:                            -11.58
# Df Residuals:                        19   BIC:                            -9.495
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
pred_log = model3.predict(pd.DataFrame(delivery_time['SortingTime']))

# %%
pred_log
# Out:
# 0     3.176888
# 1     2.543578
# 2     2.754681
# 3     3.071336
# 4     3.176888
# 5     2.754681
# 6     2.860233
# 7     2.438027
# 8     3.176888
# 9     3.071336
# 10    2.965785
# 11    2.543578
# 12    2.860233
# 13    2.438027
# 14    2.438027
# 15    2.543578
# 16    2.754681
# 17    2.860233
# 18    2.332475
# 19    2.860233
# 20    2.649130
# dtype: float64

# %%
pred3=np.exp(pred_log)  # as we have used log(AT) in preparing model so we need to convert it back
pred3
# Out:
# 0     23.972032
# 1     12.725123
# 2     15.716034
# 3     21.570707
# 4     23.972032
# 5     15.716034
# 6     17.465597
# 7     11.450423
# 8     23.972032
# 9     21.570707
# 10    19.409927
# 11    12.725123
# 12    17.465597
# 13    11.450423
# 14    11.450423
# 15    12.725123
# 16    15.716034
# 17    17.465597
# 18    10.303411
# 19    17.465597
# 20    14.141728
# dtype: float64

# %%
rmse_exp = np.sqrt(np.mean((np.array(delivery_time['DeliveryTime'])-np.array(pred3))**2))
rmse_exp
# Out:
# 2.9402503230562007

# %%
pred3.corr(delivery_time.DeliveryTime)
# Out:
# 0.8085780108289259

# %%
plt.scatter(x=delivery_time['SortingTime'],y=delivery_time['DeliveryTime'],color='green')
plt.plot(delivery_time.SortingTime,pred3,color='blue')
plt.xlabel('SortingTime')
plt.ylabel('DeliveryTime')
# Out:
# Text(0, 0.5, 'DeliveryTime')

# %%
plt.plot(delivery_time['SortingTime'],delivery_time['DeliveryTime'], 'bo')
plt.plot(delivery_time.SortingTime,pred3,color='red')

# %%
Delivery_resid = model3.resid_pearson
Delivery_resid
# Out:
# array([-0.75408795,  0.33675889,  1.3016092 ,  0.60797197,  1.08475764,
#        -0.13425573,  0.47972269, -1.06383166, -1.66402537, -0.79839415,
#         0.12198057, -0.9609301 , -0.26219179,  0.02461332,  0.28130094,
#         0.89124014, -0.7613643 ,  0.20640995, -1.44153627,  0.11763994,
#         2.38661208])

# %%
plt.scatter(x=pred3,y=delivery_time.DeliveryTime)
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(0, 0.5, 'Actual')

# %%
delivery_time["Sorting_sq"] = delivery_time.SortingTime*delivery_time.SortingTime
delivery_time
# Out:
#     DeliveryTime  SortingTime  Sorting_sq
# 0          21.00           10         100
# 1          13.50            4          16
# 2          19.75            6          36
# 3          24.00            9          81
# 4          29.00           10         100
# 5          15.35            6          36
# 6          19.00            7          49
# 7           9.50            3           9
# 8          17.90           10         100
# 9          18.75            9          81
# 10         19.83            8          64
# 11         10.75            4          16
# 12         16.68            7          49
# 13         11.50            3           9
# 14         12.03            3           9
# 15         14.88            4          16
# 16         13.75            6          36
# 17         18.11            7          49
# 18          8.00            2           4
# 19         17.83            7          49
# 20         21.50            5          25

# %%
model_quad = smf.ols("np.log(DeliveryTime)~SortingTime+Sorting_sq",data=delivery_time).fit()
#model_quad.params

# %%
model_quad.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     np.log(DeliveryTime)   R-squared:                       0.765
# Model:                              OLS   Adj. R-squared:                  0.739
# Method:                   Least Squares   F-statistic:                     29.28
# Date:                  Thu, 22 Feb 2024   Prob (F-statistic):           2.20e-06
# Time:                          06:25:02   Log-Likelihood:                 9.9597
# No. Observations:                    21   AIC:                            -13.92
# Df Residuals:                        18   BIC:                            -10.79
# Df Model:                             2
# Covariance Type:              nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
pred_quad = model_quad.predict(delivery_time)
pred4=np.exp(pred_quad)  # as we have used log(AT) in preparing model so we need to convert it back
pred4
# Out:
# 0     21.646921
# 1     12.909227
# 2     16.995933
# 3     21.176938
# 4     21.646921
# 5     16.995933
# 6     18.764526
# 7     10.825502
# 8     21.646921
# 9     21.176938
# 10    20.191891
# 11    12.909227
# 12    18.764526
# 13    10.825502
# 14    10.825502
# 15    12.909227
# 16    16.995933
# 17    18.764526
# 18     8.847949
# 19    18.764526
# 20    15.003730
# dtype: float64

# %%
rmse_quad = np.sqrt(np.mean((np.array(delivery_time['DeliveryTime'])-np.array(pred4))**2))
rmse_quad
# Out:
# 2.799041988740932

# %%
plt.scatter(delivery_time.SortingTime,delivery_time.DeliveryTime,c="b")
plt.plot(delivery_time.SortingTime,pred4,"r")

# %%
data = {"MODEL":pd.Series(["rmse_lin","rmse_log","rmse_exp","rmse_quad"]),
        "RMSE_Values":pd.Series([rmse_lin,rmse_log,rmse_exp,rmse_quad]),
        "Rsquare":pd.Series([model.rsquared,model2.rsquared,model3.rsquared,model_quad.rsquared])}
table=pd.DataFrame(data)
table
# Out:
#        MODEL  RMSE_Values   Rsquare
# 0   rmse_lin     2.791650  0.682271
# 1   rmse_log     2.733171  0.695443
# 2   rmse_exp     2.940250  0.710948
# 3  rmse_quad     2.799042  0.764867

# %%
import matplotlib.pyplot as plt
>>> plt.style.use('classic')

# %%
plt.hist(model_quad.resid_pearson)
plt.show()

# %%
plt.scatter(delivery_time.SortingTime,delivery_time.DeliveryTime,c="b")
plt.plot(delivery_time.SortingTime,pred4,"r")
